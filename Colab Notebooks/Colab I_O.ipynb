# %% [markdown]
# # PyDrive

# %% [markdown]
# ## (URL >> Colab)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

try:
    from urllib.request import urlopen # python 3
except ImportError:
    from urllib2 import urlopen # python 2
import sys
import tarfile
import tempfile
import shutil

url = "http://hizalcelik.com/dev/cities.tar"

with tempfile.TemporaryFile() as tmp:
    print("Downloading", url)
    shutil.copyfileobj(urlopen(url), tmp)
    print("Extracting")
    tmp.seek(0)
    if ".tar" in url or ".tgz" in url:
      tar = tarfile.open(fileobj=tmp)
      tar.extractall()
      tar.close()
    print("Done")
# Out:
# ...
# Extracting
# Done

# %% [markdown]
# ## (Browser >> Colab)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b1902f41-f808-4dc4-95c7-9781b0f56bb2" name="files[]" multiple disabled />
#      <output id="result-b1902f41-f808-4dc4-95c7-9781b0f56bb2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image.jpg to image.jpg

# %% [markdown]
# ## (Drive >> Colab)

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create GoogleDrive instance with authenticated GoogleAuth instance.
drive = GoogleDrive(gauth)

# %%
id = "1cNuQHPBzXdtOupcpiGCKy-_yB0MzhNo4"
filename = "cover.jpg"
file = drive.CreateFile({'id': id})
file.GetContentFile(filename)
print('%s (%s) downlaoded' % (file['title'], file['mimeType']))
# Out:
# cover.jpg (image/jpeg) downlaoded

# %% [markdown]
# ## (Colab >> Drive)

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create GoogleDrive instance with authenticated GoogleAuth instance.
drive = GoogleDrive(gauth)

# %%
filename = "ARCHIVE.tar.gz"
file = drive.CreateFile()
file.SetContentFile(filename)
file.Upload()
print('%s (%s) uploaded' % (file['title'], file['mimeType']))

# %% [markdown]
# ## (Colab >> Browser)

# %%
from google.colab import files
filename = "ARCHIVE.tar.gz"
files.download(filename)
print ("%s downloaded" % (filename))

# %% [markdown]
# ## CLI Reference

# %%
# new folder
mkdir FOLDER

# delete folder
rm -r FOLDER

# delete file
rm FILE

# move file
mv path/to/FILE path/to/dest/FILE

# copy
[see online]

# get size
du -hs FOLDER/FILE

# zip
zip -r ARCHIVE.zip FOLDER/FILE

# tar
tar -czvf ARCHIVE.tar.gz FOLDER/FILE

# %% [markdown]
# ### Misc
# (scratch code for testing)

# %%
# JUNK STUFF
# !ls
# Out:
# ARCHIVE.tar.gz	cities	cover.jpg  datalab  image.jpg  test  test.tar.gz
